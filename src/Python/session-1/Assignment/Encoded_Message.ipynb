# %%
message="###!!@mocleW EPGTQ!!!6789"
message=message[6:-7] # moclew EPGTQ
print(message)

message[:6][::-1] # moclew -> welcom
message=message.replace(message[:6], message[:6][::-1]) # welcom EPGTQ
print(message)

message=message.replace(message[7],'') # welcom PGTQ

print(message)
# Out:
# mocleW EPGTQ
# Welcom EPGTQ
# Welcom PGTQ
