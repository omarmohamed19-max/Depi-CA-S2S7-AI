# %%
print("my name is omar")
# Out:
# my name is omar

# %%
print("my name is omar", 30)
# Out:
# my name is omar 30

# %%
x=10
hex(id(x))
# Out:
# '0x7ff92de994c8'

# %%
x=10 # this is variable is int type
'''  
this app help 
user
to
learn 
python

'''
# Out:
# '  \nthis app help \nuser\nto\nlearn \npython\n\n'

# %%
x=10
print(type(x)) # this is variable is int type
# Out:
# <class 'int'>

# %%
name='omar'
print("my name is {0}".format(name))
# Out:
# my name is omar

# %%
name='omar'
age=20
course_name='python'
output=f"my name is {name} and my age is {age} and my course name is {course_name}"
print(output)
# Out:
# my name is omar and my age is 20 and my course name is python

# %%
x=[1,2,3,4,5]
print(type(x)) # this is variable is list type
print(x[0]) # this is variable is list type
x[0]=10
print(x[0]) # this is variable is list type
# Out:
# <class 'list'>
# 1
# 10

# %%
x=(1,2,3,4,5)
print(type(x)) # this is variable is tuple type
print(x[0]) # this is variable is tuple type
# Out:
# <class 'tuple'>
# 1

# %%
x={1,2,3,4,5}
print(type(x)) # this is variable is set type
# Out:
# <class 'set'>

# %%
dic1={'name':'omar','age':20,'course_name':'python'}
print(type(dic1)) # this is variable is dict type
# Out:
# <class 'dict'>

# %%
name="depi for everyone"
name[5:8:1]
print(name[5:8:1])
# Out:
# for

# %%
name="depi for machine learning"
capital=name.upper()
print(capital.lower())
# Out:
# depi for machine learning

# %%
name="depi for machine learning"
name=name.replace('machine',"deep learning")
print(name)
# Out:
# depi for deep learning learning

# %%
name="depi for machine learning"
print(name.capitalize()) # This will capitalize the first letter of the string
print(name.title()) # This will capitalize the first letter of each word in the string
# Out:
# Depi for machine learning
# Depi For Machine Learning

# %%
name="depi for machine learning"

x=name.split() # This will split the string into a list of words
print(x)

x=" ".join(x) # This will join the list of words into a string
print(x)
# Out:
# ['depi', 'for', 'machine', 'learning']
# depi for machine learning
