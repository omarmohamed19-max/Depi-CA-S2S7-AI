# %%
import pandas as pd
#df = pd.read_csv("Titanic.csv")
from config import data_path
def read_file(file_path):
    df= pd.read_csv(file_path)
    return df

read_file(data_path)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[23], line 3
#       1 import pandas as pd
#       2 #df = pd.read_csv("Titanic.csv")
# ----> 3 from config import data_path
#       4 def read_file(file_path):
#       5     df= pd.read_csv(file_path)
#       6     return df
#
# ImportError: cannot import name 'data_path' from 'config' (x:\Desktop\AI_depi\ML-depi\Depi-CA-S2S7-AI\src\DA\session-3\code\config.py)

# %%
df= pd.read_csv("Titanic.csv")

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
#df.drop(['PassengerId','Name','Ticket'],axis=1,inplace=True)

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
from config import cols_drop
df.drop(cols_drop,axis=1,inplace=True)

# %%
df.head()
# Out:
#    Survived  Pclass     Sex   Age  SibSp  Parch     Fare Cabin Embarked
# 0         0       3    male  22.0      1      0   7.2500   NaN        S
# 1         1       1  female  38.0      1      0  71.2833   C85        C
# 2         1       3  female  26.0      0      0   7.9250   NaN        S
# 3         1       1  female  35.0      1      0  53.1000  C123        S
# 4         0       3    male  35.0      0      0   8.0500   NaN        S

# %%
#cols_drop=['PassengerId','Name','Ticket']
#df.drop(cols_drop,axis=1,inplace=True)

# %%
from config import cols_drop
def drop_cols(df:pd.DataFrame,cols:list[str])->pd.DataFrame:
    
    return df.drop(columns=cols)

# %%
dtype=df.dtypes
nunique= df.nunique()
pd.DataFrame({"dtype":dtype, "nunique":nunique}).T
# Out:
#         Survived Pclass  Sex      Age  SibSp  Parch     Fare Cabin Embarked
# dtype      int64  int64  str  float64  int64  int64  float64   str      str
# nunique        2      3    2       88      7      7      248   147        3

# %%
cols=["Survived",'Pclass','Sex','Age','SibSp','Parch']
df[cols]=df[cols].astype("category")

# %%
def get_data_info(df):
    return pd.DataFrame({"dtype":df.dtype, "nunique":df.nunique()}).T

# %%
null=df.isnull().sum()
ratio=(null/891)*100
print(ratio)
pd.DataFrame({"Null":null,"ratio":ratio}).T
# Out:
# Survived     0.000000
# Pclass       0.000000
# Sex          0.000000
# Age         19.865320
# SibSp        0.000000
# Parch        0.000000
# Fare         0.000000
# Cabin       77.104377
# Embarked     0.224467
# dtype: float64
#        Survived  Pclass  Sex        Age  SibSp  Parch  Fare       Cabin  \
# Null        0.0     0.0  0.0  177.00000    0.0    0.0   0.0  687.000000
# ratio       0.0     0.0  0.0   19.86532    0.0    0.0   0.0   77.104377
#
#        Embarked
# Null   2.000000
# ratio  0.224467

# %%
df.info(
)
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  891 non-null    category
#  1   Pclass    891 non-null    category
#  2   Sex       891 non-null    category
#  3   Age       714 non-null    category
#  4   SibSp     891 non-null    int64
#  5   Parch     891 non-null    int64
#  6   Fare      891 non-null    float64
#  7   Cabin     204 non-null    str
#  8   Embarked  889 non-null    str
# dtypes: category(4), float64(1), int64(2), str(2)
# memory usage: 39.2 KB

# %%
df=df.dropna(subset=['Embarked'])

# %%
df=df.drop("Cabin",axis=1)

# %%
df.describe()
# Out:
#             SibSp       Parch        Fare
# count  889.000000  889.000000  889.000000
# mean     0.524184    0.382452   32.096681
# std      1.103705    0.806761   49.697504
# min      0.000000    0.000000    0.000000
# 25%      0.000000    0.000000    7.895800
# 50%      0.000000    0.000000   14.454200
# 75%      1.000000    0.000000   31.000000
# max      8.000000    6.000000  512.329200

# %%
madian=df["Age"].median()
df['Age']=df["Age"].fillna(madian)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[43], line 1
# ----> 1 madian=df["Age"].median()
#       2 df['Age']=df["Age"].fillna(madian)
#
# File c:\Users\Lenovo\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\util\_decorators.py:336, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     330 if len(args) > num_allow_args:
#     331     warnings.warn(
#     332         msg.format(arguments=_format_argument_list(allow_args)),
#     333         klass,
#     334         stacklevel=find_stack_level(),
#     335     )
# --> 336 return func(*args, **kwargs)
#
# File c:\Users\Lenovo\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\series.py:8196, in Series.median(self, axis, skipna, numeric_only, **kwargs)
#    8117 @deprecate_nonkeyword_arguments(
#    8118     Pandas4Warning, allowed_args=["self"], name="median"
#    8119 )
#    (...)   8125     **kwargs,
#    8126 ) -> Any:
#    8127     """
#    8128     Return the median of the values over the requested axis.
#    8129
#    (...)   8194     dtype: float64
#    8195     """
# -> 8196     return NDFrame.median(
#    8197         self, axis=axis, skipna=skipna, numeric_only=numeric_only, **kwargs
#    8198     )
#
# File c:\Users\Lenovo\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\generic.py:11843, in NDFrame.median(self, axis, skipna, numeric_only, **kwargs)
#   11839         skipna: bool = True,
#   11840         numeric_only: bool = False,
#   11841         **kwargs,
#   11842     ) -> Series | float:
# > 11843         return self._stat_function(
#   11844             "median", nanops.nanmedian, axis, skipna, numeric_only, **kwargs
#   11845         )
#
# File c:\Users\Lenovo\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\generic.py:11785, in NDFrame._stat_function(self, name, func, axis, skipna, numeric_only, **kwargs)
#   11781         nv.validate_func(name, (), kwargs)
#   11782
#   11783         validate_bool_kwarg(skipna, "skipna", none_allowed=False)
#   11784
# > 11785         return self._reduce(
#   11786             func, name=name, axis=axis, skipna=skipna, numeric_only=numeric_only
#   11787         )
#
# File c:\Users\Lenovo\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\series.py:7480, in Series._reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    7476     self._get_axis_number(axis)
#    7478 if isinstance(delegate, ExtensionArray):
#    7479     # dispatch to ExtensionArray interface
# -> 7480     result = delegate._reduce(name, skipna=skipna, **kwds)
#    7482 else:
#    7483     # dispatch to numpy arrays
#    7484     if numeric_only and self.dtype.kind not in "iufcb":
#    7485         # i.e. not is_numeric_dtype(self.dtype)
#
# File c:\Users\Lenovo\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\arrays\categorical.py:2455, in Categorical._reduce(self, name, skipna, keepdims, **kwargs)
#    2452 def _reduce(
#    2453     self, name: str, *, skipna: bool = True, keepdims: bool = False, **kwargs
#    2454 ):
# -> 2455     result = super()._reduce(name, skipna=skipna, keepdims=keepdims, **kwargs)
#    2456     if name in ["argmax", "argmin"]:
#    2457         # don't wrap in Categorical!
#    2458         return result
#
# File c:\Users\Lenovo\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\arrays\base.py:2371, in ExtensionArray._reduce(self, name, skipna, keepdims, **kwargs)
#    2369 meth = getattr(self, name, None)
#    2370 if meth is None:
# -> 2371     raise TypeError(
#    2372         f"'{type(self).__name__}' with dtype {self.dtype} "
#    2373         f"does not support operation '{name}'"
#    2374     )
#    2375 result = meth(skipna=skipna, **kwargs)
#    2376 if keepdims:
#
# TypeError: 'Categorical' with dtype category does not support operation 'median'

# %%
null=df.isnull().sum()
ratio=(null/891)*100
print(ratio)
pd.DataFrame({"Null":null,"ratio":ratio}).T
# Out:
# Survived     0.00000
# Pclass       0.00000
# Sex          0.00000
# Age         19.86532
# SibSp        0.00000
# Parch        0.00000
# Fare         0.00000
# Embarked     0.00000
# dtype: float64
#        Survived  Pclass  Sex        Age  SibSp  Parch  Fare  Embarked
# Null        0.0     0.0  0.0  177.00000    0.0    0.0   0.0       0.0
# ratio       0.0     0.0  0.0   19.86532    0.0    0.0   0.0       0.0

# %%
def null_info(df):
    null=df.isnull().sum()
    ratio=(null/df.shape[0])*100
    return pd.DataFrame({"Null":null,"ratio":ratio}).T
